# %% [markdown]
# # 富士山から下りたい

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
np.set_printoptions(suppress=True) # 指数表示の禁止を設定する
fuji = np.loadtxt("mtfuji_data.csv",delimiter=",", skiprows=1)

# %%
print(fuji)
print(fuji.shape)
# Out:
# [[    0.          35.134141   139.132082     0.           0.      ]
#  [    1.          35.135826   139.129202     0.         322.      ]
#  [    2.          35.13751    139.126322     0.         644.      ]
#  ...
#  [  297.          35.631284   138.271368  1973.99     95698.      ]
#  [  298.          35.632947   138.268452  1841.36     96020.      ]
#  [  299.          35.63461    138.265536  1725.8      96343.      ]]
# (300, 5)

# %% [markdown]
# 【問題1】断面図の作成

# %%
plt.xlabel('x')
plt.ylabel('evaluation[m]')
plt.vlines(136, 0, 4000)
plt.plot(fuji[0:, 0], fuji[0:, 3])
plt.show()

# %% [markdown]
# 【問題2】ある地点の勾配を計算する関数を作成

# %%
def compute_grad(x):
    grad = (fuji[x, 3] - fuji[x-1, 3]) / (fuji[x, 0] - fuji[x-1, 0])
    return grad

point = int(input('今いる地点を入力してください:'))
y = compute_grad(point)
print('勾配：{}'.format(y))
# Out:
# 今いる地点を入力してください:111
# 勾配：46.1099999999999

# %% [markdown]
# 【問題3】移動先の地点を計算する関数を作成

# %%
alpha = 0.2
def compute_grad3(x):
    grad = (fuji[x, 3] - fuji[x-1, 3]) / (fuji[x, 0] - fuji[x-1, 0])
    point = fuji[x, 0] - alpha * grad
    if point < 0 or point > 300:
        print('存在しない地点です。移動距離か地点を選び直してください。')
    else:
        return int(point)

point = int(input('今いる地点を入力してください:'))
y = compute_grad3(point)
print(' 移動先は{}です'.format(y))
# Out:
# 今いる地点を入力してください:111
#  移動先は101です

# %% [markdown]
# 【問題4】山を下る関数を作成

# %%
# alpha = 0.001
def compute_grad4(x, alpha=0.05):
    check_point = []
    check_point.append(x)
    while True:
        grad = (fuji[x, 3] - fuji[x-1, 3]) / (fuji[x, 0] - fuji[x-1, 0])
        point = fuji[x, 0] - alpha * grad
        point = int(point)
#         print(point)
        if point < 0 or point > 300:
            print('存在しない地点です。移動距離(学習率)か地点を選び直してください。')
            break
        else:
            x = point
            if point == check_point[-1]:
                break
            else:
                check_point.append(point)
        
    return check_point

point = int(input('今いる地点を入力してください:'))
result4 = compute_grad4(point)
print(' 移動履歴:', result4)
# Out:
# 今いる地点を入力してください:136
#  移動履歴: [136, 127, 120, 118, 114, 112, 108, 106, 104, 102, 100, 99, 98, 97, 95, 94, 92, 91, 90, 89, 87, 86, 85, 84, 83, 82, 81, 79, 77, 76, 75, 74, 73, 72]

# %% [markdown]
# 【問題5】下山過程の可視化

# %%
plt.title('Mt fuji')
plt.xlabel("count")
plt.ylabel("point")
plt.tick_params(labelsize=20) # 軸の値に関する設定を行う
plt.plot(fuji[result4, 3], marker='*')
plt.show()

# %% [markdown]
# 【問題6】初期値の変更

# %%
log = []
# print(len(fuji))
for i in range(len(fuji)):
    print('{}回目'.format(i))
    y = compute_grad4(i, alpha=0.001)
    log.append(y)
# Out:
# 0回目
# 1回目
# 2回目
# 3回目
# 4回目
# 5回目
# 6回目
# 7回目
# 8回目
# 9回目
# 10回目
# 11回目
# 12回目
# 13回目
# 14回目
# 15回目
# 16回目
# 17回目
# 18回目
# 19回目
# 20回目
# 21回目
# 22回目
# 23回目
# 24回目
# 25回目
# 26回目
# 27回目
plt.tick_params(labelsize=20) # 軸の値に関する設定を行う
plt.plot(fuji[log[136],3], marker='*')
plt.show()

plt.title('Mt fuji 125 of point')
plt.xlabel("count")
plt.ylabel("point")
plt.tick_params(labelsize=20) # 軸の値に関する設定を行う
plt.plot(fuji[log[130],3], marker='*')
plt.show()

plt.title('Mt fuji 10 of point')
plt.xlabel("count")
plt.ylabel("point")
plt.tick_params(labelsize=20) # 軸の値に関する設定を行う
plt.plot(fuji[log[10],3], marker='*')
plt.show()

# %% [markdown]
# 【問題7】（アドバンス問題）ハイパーパラメータの変更

# %%
point = int(input('今いる地点を入力してください:'))
result5 = compute_grad4(point, alpha=0.05)
plt.title('Mt fuji')
plt.xlabel("count")
plt.ylabel("point")
plt.tick_params(labelsize=20) # 軸の値に関する設定を行う
plt.plot(fuji[result5,3], marker='*')
plt.show()
# Out:
# 今いる地点を入力してください:136

# %%
point = int(input('今いる地点を入力してください:'))
result6 = compute_grad4(point, alpha=0.0001)
print(result6)
plt.title('Mt fuji')
plt.xlabel("count")
plt.ylabel("point")
plt.tick_params(labelsize=20) # 軸の値に関する設定を行う
plt.plot(fuji[result6, 3], marker='*')
plt.show()
# Out:
# 今いる地点を入力してください:136
# [136, 135, 134, 133, 132, 131, 130, 129, 128, 127, 126, 125, 124, 123, 122, 121, 120, 119, 118, 117, 116, 115, 114, 113, 112, 111, 110, 109, 108, 107, 106, 105, 104, 103, 102, 101, 100, 99, 98, 97, 96, 95, 94, 93, 92, 91, 90, 89, 88, 87, 86, 85, 84, 83, 82, 81, 80, 79, 78, 77, 76, 75, 74, 73, 72]

# %% [markdown]
# 確率的勾配降下法実装してみた<br>
# 参考サイト：https://postd.cc/optimizing-gradient-descent/<br>
# https://qiita.com/YudaiSadakuni/items/ece07b04c685a64eaa01

# %%
np.random.shuffle(fuji)
print(fuji)
# Out:
# [[   34.          35.191365   139.034084   864.06     10955.      ]
#  [  139.          35.367579   138.730571  3664.9      44788.      ]
#  [  251.          35.554691   138.40537   1079.27     80876.      ]
#  ...
#  [   51.          35.219947   138.985033   880.44     16433.      ]
#  [  183.          35.441192   138.602993   960.52     58965.      ]
#  [  185.          35.444535   138.597188  1094.28     59610.      ]]

# %%
def prob_compute_grad(x, data, epochs, alpha=0.05):
    log = []
    for epoch in range(epochs):
        check_point = []
        check_point.append(x)
        np.random.shuffle(data)
        while True:
            grad = (data[x, 3] - data[x-1, 3]) / (data[x, 0] - data[x-1, 0])
            point = data[x, 0] - alpha * grad
            point = int(point)
#             print(point)
            if point < 0 or point > 300:
                print('存在しない地点です。移動距離(学習率)か地点を選び直してください。')
                break
            else:
                x = point
                if point not in check_point:
                    check_point.append(point)
                else:
                     break
        log.append(check_point)
    return log

# %%
point = int(input('今いる地点を入力してください:'))
epochs = 10
log = prob_compute_grad(point, fuji, epochs, alpha=0.001)
for i in range(epochs):
    plt.title('Mt fuji {}'.format(i))
    plt.xlabel("height")
    plt.ylabel("point")
    plt.tick_params(labelsize=20) # 軸の値に関する設定を行う
    plt.plot(fuji[log[i], 3], marker='*')
    plt.show()
# Out:
# 今いる地点を入力してください:136

# %% [markdown]
# ミニバッチ勾配降下法実装してみた

# %%
def get_batches(data, batch_size=50):
    batch_list = []
    for i in range(0, len(data), batch_size):
        batch = data[i:i+batch_size]
        batch_list.append(batch)
    batch_list = np.array(batch_list)
    return batch_list

def min_batch_compute_grad(data, epochs, alpha=0.05):
    log = []
    for epoch in range(epochs):
        np.random.shuffle(data)
        batch_check_point = []
        for batch in get_batches(data, batch_size=50):
            check_point = []
            x = np.random.choice(batch[:, 0])
            x = round(x)
            check_point.append(x)
            while True:
                grad = (batch[x, 3] - batch[x, 3]) / (batch[x, 0] - batch[x-1, 0])
                point = batch[x, 0] - alpha * grad
                point = int(point)
#                 print(point)
                if point not in batch[:,0]:
                    print('存在しない地点です。移動距離(学習率)か地点を選び直してください。')
                    break
                else:
                    x = point
                    if point not in check_point:
                        check_point.append(point)
                    else:
                         break
            batch_check_point.append(check_point)
        log.append(batch_check_point)
    return log

# %%
a = get_batches(fuji)
print(a.shape)
print(a)
# Out:
# (6, 50, 5)
# [[[   23.          35.17286    139.065804   628.22      7411.      ]
#   [  147.          35.380973   138.707392  2450.23     47366.      ]
#   [  186.          35.446206   138.594286  1203.92     59932.      ]
#   ...
#   [  275.          35.594671   138.335488  1438.39     88609.      ]
#   [  105.          35.310603   138.828995   910.5      33832.      ]
#   [   35.          35.193047   139.031199   826.52     11277.      ]]
#
#  [[  271.          35.58801    138.347139  1680.01     87321.      ]
#   [  205.          35.477948   138.539117   620.23     66054.      ]
#   [  266.          35.579683   138.361702  1878.56     85709.      ]
#   ...
#   [   88.          35.282085   138.878156   553.64     28355.      ]
#   [  136.          35.362555   138.739261  3434.59     43821.      ]
#   [  170.          35.419457   138.640711  1160.85     54777.      ]]
#
#  [[   92.          35.288797   138.866591   613.04     29644.      ]
#   [  144.          35.375951   138.716085  2864.56     46399.      ]
#   [  249.          35.551357   138.41119    915.92     80232.      ]
#   ...
#   [   20.          35.167812   139.074453   580.5       6444.      ]
#   [  238.          35.533018   138.443194   437.7      76687.      ]
#   [  242.          35.539687   138.431558   462.99     77976.      ]]
#
#  [[   95.          35.29383    138.857917   672.36     30610.      ]
#   [   44.          35.20818    139.005234   724.5      14177.      ]
#   [  106.          35.31228    138.826102   932.74     34155.      ]
#   ...
#   [  184.          35.442864   138.600091   958.44     59288.      ]
#   [  143.          35.374277   138.718982  3019.8      46077.      ]
#   [  281.          35.60466    138.318006  1337.45     90543.      ]]
#
#  [[  211.          35.487966   138.521686   361.49     67987.      ]
#   [  181.          35.437849   138.608797   985.66     58321.      ]
#   [   56.          35.228349   138.970599   738.97     18044.      ]
#   ...
#   [  273.          35.591341   138.341314  1635.28     87965.      ]
#   [   10.          35.15098    139.103273   171.56      3222.      ]
#   [  172.          35.422802   138.634909  1095.73     55421.      ]]
#
#  [[  241.          35.53802    138.434467   430.96     77654.      ]
#   [  187.          35.447878   138.591383  1321.2      60254.      ]
#   [  160.          35.402729   138.66971   1484.72     51554.      ]
#   ...
#   [  294.          35.626293   138.280115  2084.51     94732.      ]
#   [  155.          35.394363   138.684206  1748.11     49943.      ]
#   [   11.          35.152664   139.100392   177.84      3544.      ]]]

# %%
epochs = 10
log = min_batch_compute_grad(fuji, epochs=epochs)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-96e112f21a69> in <module>
#       1 epochs = 10
# ----> 2 log = min_batch_compute_grad(fuji, epochs=epochs)
#
# <ipython-input-64-a05f13e12d53> in min_batch_compute_grad(data, epochs, alpha)
#      18             check_point.append(x)
#      19             while True:
# ---> 20                 grad = (batch[x, 3] - batch[x-1, 3]) / (batch[x, 0] - batch[x-1, 0])
#      21                 point = batch[x, 0] - alpha * grad
#      22                 point = int(point)
#
# IndexError: index 207 is out of bounds for axis 0 with size 50
